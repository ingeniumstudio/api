# %%
from functions import text_to_image

# %% [markdown]
# https://ipython.readthedocs.io/en/9.1.0/api/generated/IPython.display.html#IPython.display.Image

# %%
# https://ipython.readthedocs.io/en/9.1.0/api/generated/IPython.display.html#IPython.display.Image
from IPython.display import Image

# %%
image_bytes = text_to_image(text="multiline,\n  padded text\n  -- remember nerdfonts!")

# %%
mage(data=image_bytes)
