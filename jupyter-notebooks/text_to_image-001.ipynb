# %%
from functions import text_to_image

# %% [markdown]
# https://ipython.readthedocs.io/en/9.1.0/api/generated/IPython.display.html#IPython.display.Image

# %%
# https://ipython.readthedocs.io/en/9.1.0/api/generated/IPython.display.html#IPython.display.Image
from IPython.display import Image

# %%
text = """\
text:
  paddded,

  ATTENTION: remember NerdFonts!\
"""

# %%
image_bytes = text_to_image(text=text,
                            padding=0)

# %%
Image(data=image_bytes)

# %%
image_bytes2 = text_to_image(text=text,
                             padding=10)

# %%
Image(data=image_bytes2)
